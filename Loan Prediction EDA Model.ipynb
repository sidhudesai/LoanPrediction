# %% [markdown]
# # Loan Prediction Classification

# %%
# This is a binary classification problem where we need to predict whether laon approved or not approved
# based on the past information of the person.

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading the DataSet
df=pd.read_csv(r'C:\Users\user\Desktop\Loan Prediction Problem\DataSet.csv')

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
#df.shape displays how many columns and rows are in the dataset
#df.dtypes displays data type of the column
df.shape, df.dtypes
# Out:
# ((614, 13), Loan_ID               object
#  Gender                object
#  Married               object
#  Dependents            object
#  Education             object
#  Self_Employed         object
#  ApplicantIncome        int64
#  CoapplicantIncome    float64
#  LoanAmount           float64
#  Loan_Amount_Term     float64
#  Credit_History       float64
#  Property_Area         object
#  Loan_Status           object
#  dtype: object)

# %%
#df.describe displays the mean, count, std, min and etc of the continous data.
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
#finding the missing values
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#Filling the Missing values for the Discrete values using MODE.Find the Mode of the Labels.
#filling the missing values for the continous values using MEAN.Fidn the mean/median of the labels.
df.Gender.value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
df.Married.value_counts()
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
df.Dependents.value_counts()
# Out:
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64

# %%
df.Self_Employed.value_counts()
# Out:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64

# %%
df.LoanAmount.median()
# Out:
# 128.0

# %%
df.Loan_Amount_Term.value_counts()
# Out:
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 84.0       4
# 240.0      4
# 120.0      3
# 36.0       2
# 60.0       2
# 12.0       1
# Name: Loan_Amount_Term, dtype: int64

# %%
df.Credit_History.value_counts()
# Out:
# 1.0    475
# 0.0     89
# Name: Credit_History, dtype: int64

# %%
df['Gender'].fillna('Male', inplace=True)#filled missing values with mode.

# %%
df['Married'].fillna('Yes', inplace=True)#filled missing values with mode.

# %%
df['Dependents'].fillna(0, inplace=True)#filled missing values with mode

# %%
df['Self_Employed'].fillna('No', inplace=True)#filled missing values with Mode

# %%
df['Loan_Amount_Term'].fillna(360, inplace=True)#filled missing values with mode

# %%
df['LoanAmount'].fillna(df.LoanAmount.median(), inplace=True)#filled missing values with median

# %%
df['Credit_History'].fillna(1.0, inplace=True)#filled missing values with Mode.

# %%
df.isnull().sum()#after filling missing values no missing values found in the data.
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# # Categorical Plots
# Seaborn also helps us in doing the analysis on Categorical Data points. In this section we will discuss about
#
# - boxplot
# - violinplot
# - countplot
# - bar plot

# %%
#Univariate Analysis
sns.countplot(df['Gender']),
df.Gender.value_counts()
#Male are applied for loan comparing with Female.
# Out:
# Male      502
# Female    112
# Name: Gender, dtype: int64

# %%
sns.countplot(df['Married']), df.Married.value_counts()
#Married people had requirement of loan comparing with Unmarried
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x228f10da748>, Yes    401
#  No     213
#  Name: Married, dtype: int64)

# %%
sns.countplot(df['Dependents']), df.Dependents.value_counts()
#Who have no dependents they applied for loan mostly.
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x228f1114c08>, 0     345
#  1     102
#  2     101
#  3+     51
#  0      15
#  Name: Dependents, dtype: int64)

# %%
sns.countplot(df['Education']),df.Education.value_counts()
# Graduates have requirement of loan than non Graduates.
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x228f1154388>, Graduate        480
#  Not Graduate    134
#  Name: Education, dtype: int64)

# %%
sns.countplot(df['Self_Employed']), df.Self_Employed.value_counts()
#Salaried people have requirement of loan rather than Not salaried.
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x228f11d3208>, No     532
#  Yes     82
#  Name: Self_Employed, dtype: int64)

# %%
sns.distplot(df['ApplicantIncome'])

# %%
sns.boxplot(df.ApplicantIncome)
# Mostly applicants applied for less amount and outliers.

# %%
plt.figure(figsize=(24,16))
plt.subplot(221)
sns.distplot(df.CoapplicantIncome)
plt.subplot(222)
sns.boxplot(df.CoapplicantIncome)
plt.show()
# Most Coappliants are applied for less amount only.

# %%
plt.figure(figsize=(24,16))
plt.subplot(223)
sns.distplot(df.LoanAmount)
plt.subplot(224)
sns.boxplot(df.LoanAmount)
plt.show()
# Mostly applicants applied for loan AMount is between 100-200.

# %%
sns.countplot(df['Loan_Amount_Term']),df.Loan_Amount_Term.value_counts()
#Most loans are applied for long term which is for 360 Months.
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x228f15dfa88>, 360.0    526
#  180.0     44
#  480.0     15
#  300.0     13
#  84.0       4
#  240.0      4
#  120.0      3
#  36.0       2
#  60.0       2
#  12.0       1
#  Name: Loan_Amount_Term, dtype: int64)

# %%
sns.countplot(df['Credit_History']), df.Credit_History.value_counts()
# Most loans applied who has good credit history
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x228f18c00c8>, 1.0    525
#  0.0     89
#  Name: Credit_History, dtype: int64)

# %%
sns.countplot(df['Property_Area']),df.Property_Area.value_counts()
# Mostly Semiurban and urban people have requirement of loan less rural people have requirement of Loan.
#Everyone has requirement of Loan
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x228f1919148>, Semiurban    233
#  Urban        202
#  Rural        179
#  Name: Property_Area, dtype: int64)

# %%
#BiVariate Analysis
gender=pd.crosstab(df['Gender'],df['Loan_Status'])
gender.plot.bar(stacked=True)
#Both Men and Female loans got approved mostly.

# %%
married=pd.crosstab(df['Married'],df['Loan_Status'])
married.plot.bar(stacked=True)
#Married people loan got approved than unmarried people.

# %%
dependents=pd.crosstab(df['Dependents'],df['Loan_Status'])
dependents.plot.bar(stacked=True)
#Mostly who have no dependents their loan got approved.

# %%
df['Dependents']=df['Dependents'].str.replace('[/+/]','')
#remove special characters in the data

# %%
df['Dependents']=df['Dependents'].astype(float)
#how to change the datatype from object to float

# %%
sns.countplot(df['Education'], hue=df['Loan_Status'])
#Graduates loan got approved than non Graduates

# %%
sns.countplot(df['Self_Employed'], hue=df['Loan_Status'])
#Mostly Non Self employed got loan approved. If we see half of the Selfemployed people loan also approved

# %%
plt.plot(df['ApplicantIncome'], df['Loan_Status'])
plt.xlabel("ApplicantIncome")
plt.ylabel("Loan_Status")
plt.title('Approval_Status')
plt.show()
#we cannot figure out by using this plotting.

# %%
bins=[0, 10000, 30000,40000,80000]
groups=['Low', 'Medium', 'High', 'Very High']
AI=pd.cut(df['ApplicantIncome'], bins, labels=groups)
AI.value_counts()
# Out:
# Low          562
# Medium        45
# High           4
# Very High      2
# Name: ApplicantIncome, dtype: int64

# %%
sns.countplot(AI, hue=df['Loan_Status'])
#Low income people applied for loan and got approval.

# %%
sns.jointplot(x='ApplicantIncome',y='CoapplicantIncome', data=df, kind='reg')
#we can perform regression for only for continous variables. relationship between both vairables is negative.

# %%
sns.distplot(df.CoapplicantIncome, kde=True, bins=3)

# %%
sns.barplot(df.Dependents, df.Married)

# %%
sns.boxplot(df.Dependents,df.Married)

# %%
plt.figure(figsize=(24,16))
sns.boxplot(data=df)
plt.show()
#it displays outliers and contribution of the data

# %%
#MultiVariate Analysis
sns.heatmap(df.corr(), annot=True)
#A correlation heatmap uses colored cells, typically in a monochromatic scale, 
#to show a 2D correlation matrix (table) between variables.
#It is very important in Feature Selection

# %%
sns.pairplot(df, hue='Loan_Status')
#A “pairs plot” is also known as a scatterplot, in which one variable in the same data row is matched with another variable's value.
#like this: Pairs plots are just elaborations on this, showing all variables paired with all the other variables
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
#Identifying relationship between variables
sns.pairplot(df, kind='scatter', hue='Loan_Status')
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\user\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
#FEATURE ENGINEERING
df.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No         0.0      Graduate            No
# 1  LP001003   Male     Yes         1.0      Graduate            No
# 2  LP001005   Male     Yes         0.0      Graduate           Yes
# 3  LP001006   Male     Yes         0.0  Not Graduate            No
# 4  LP001008   Male      No         0.0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.CoapplicantIncome.tail()
# Out:
# 609      0.0
# 610      0.0
# 611    240.0
# 612      0.0
# 613      0.0
# Name: CoapplicantIncome, dtype: float64

# %%
df.CoapplicantIncome.value_counts()
# Out:
# 0.0       273
# 1666.0      5
# 2083.0      5
# 2500.0      5
# 1750.0      3
#          ...
# 7166.0      1
# 2138.0      1
# 2166.0      1
# 3541.0      1
# 3021.0      1
# Name: CoapplicantIncome, Length: 287, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
#convert the categorical data into numeric data

# %%
le=LabelEncoder()
#Using LabelEncoder we have changed the categorical data into numberic data.

# %%
df.Gender=le.fit_transform(df['Gender'])
df.Married=le.fit_transform(df['Married'])
df.Education=le.fit_transform(df['Education'])
df.Self_Employed=le.fit_transform(df['Self_Employed'])
df.Property_Area=le.fit_transform(df['Property_Area'])

# %%
df.head()
# Out:
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP001002       1        0         0.0          0              0
# 1  LP001003       1        1         1.0          0              0
# 2  LP001005       1        1         0.0          0              1
# 3  LP001006       1        1         0.0          1              0
# 4  LP001008       1        0         0.0          0              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History  Property_Area Loan_Status
# 0             1.0              2           Y
# 1             1.0              0           N
# ...

# %%
#Convert the Categorical vairables into dummy variables using dummies
df=pd.get_dummies(data=df, columns=['Gender', 'Married', 'Education','Self_Employed', 'Property_Area'], drop_first=True)

# %%
df.head()
# Out:
#     Loan_ID  Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0  LP001002         0.0             5849                0.0       128.0
# 1  LP001003         1.0             4583             1508.0       128.0
# 2  LP001005         0.0             3000                0.0        66.0
# 3  LP001006         0.0             2583             2358.0       120.0
# 4  LP001008         0.0             6000                0.0       141.0
#
#    Loan_Amount_Term  Credit_History  Loan_Status  Gender_1  Married_1  \
# 0             360.0             1.0            1         1          0
# 1             360.0             1.0            0         1          1
# 2             360.0             1.0            1         1          1
# 3             360.0             1.0            1         1          1
# 4             360.0             1.0            1         1          0
#
#    Education_1  Self_Employed_1  Property_Area_1  Property_Area_2
# ...

# %%
df['Loan_Status']=le.fit_transform(df['Loan_Status'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 14 columns):
# Loan_ID              614 non-null object
# Dependents           599 non-null float64
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           614 non-null float64
# Loan_Amount_Term     614 non-null float64
# Credit_History       614 non-null float64
# Loan_Status          614 non-null int32
# Gender_1             614 non-null uint8
# Married_1            614 non-null uint8
# Education_1          614 non-null uint8
# Self_Employed_1      614 non-null uint8
# Property_Area_1      614 non-null uint8
# Property_Area_2      614 non-null uint8
# dtypes: float64(5), int32(1), int64(1), object(1), uint8(6)
# memory usage: 39.7+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID                0
# Gender                 0
# Married                0
# Dependents           614
# Education              0
# Self_Employed          0
# ApplicantIncome        0
# CoapplicantIncome      0
# LoanAmount             0
# Loan_Amount_Term       0
# Credit_History         0
# Property_Area          0
# Loan_Status            0
# dtype: int64

# %%
x=df.drop(['Loan_ID', 'Loan_Status'], axis=1)
y=df['Loan_Status']

# %%
#Model Selection
#Split the Data
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
#Transforming the data
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x_train=ss.fit_transform(x_train)
x_test=ss.transform(x_test)

# %%
#Building the Model
#Import required algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

# %%
x_train
# Out:
# array([[ 1.22661406,  0.03506585, -0.56478468, ..., -0.40323892,
#         -0.77893618,  1.4444137 ],
#        [-0.75210185,  0.28852575, -0.56478468, ...,  2.47991935,
#         -0.77893618, -0.69232243],
#        [-0.75210185, -0.21122209, -0.56478468, ..., -0.40323892,
#          1.28380222, -0.69232243],
#        ...,
#        [-0.75210185,  0.67901574, -0.56478468, ..., -0.40323892,
#          1.28380222, -0.69232243],
#        [-0.75210185, -0.37861855, -0.56478468, ..., -0.40323892,
#         -0.77893618,  1.4444137 ],
#        [ 0.2372561 , -0.1440804 , -0.56478468, ..., -0.40323892,
#         -0.77893618, -0.69232243]])

# %%
lr=LogisticRegression()
knc=KNeighborsClassifier(n_neighbors=10)
cart=DecisionTreeClassifier(criterion='gini', splitter='best', min_samples_split=5)
svc=SVC(C=2.0, kernel='sigmoid')
gnb=GaussianNB()
